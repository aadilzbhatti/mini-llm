# %%
import sys
import os

# Assuming the text_prediction module is in the 'src' directory
module_path = "/Users/aadil/Documents/Workspace/ml-projects/wiki-llm/src/"  # Replace with the correct path to your 'src' directory
if module_path not in sys.path:
    sys.path.append(module_path)

from text_prediction.live_plotter import live_plot

# Path to the metadata file
metadata_file = "../models/checkpoints/7cd4ece9bbf940d5aa43d914c854ee50/training_metadata.json"

# Call the live_plot function
live_plot(metadata_file, iterations=10000, interval=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      12 metadata_file = "../models/checkpoints/7cd4ece9bbf940d5aa43d914c854ee50/training_metadata.json"
#      14 # Call the live_plot function
# ---> 15 live_plot(metadata_file, iterations=10000, interval=5)
#
# File ~/mini-llm/src/text_prediction/live_plotter.py:52, in live_plot(metadata_file, iterations, interval)
#      50     clear_output(wait=True)
#      51     display(fig)
# ---> 52     time.sleep(interval)  # Update every interval seconds
#      54 plt.ioff()
#      55 plt.show()
#
# KeyboardInterrupt:
