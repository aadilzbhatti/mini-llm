# %%
import sys
sys.path.append('/home/ubuntu/mini-llm/src')

from live_plotter import live_plot

# Path to the metadata file
metadata_file = "../models/optuna_checkpoints/trial_0/training_metadata.json"

# Call the live_plot function
live_plot(metadata_file, iterations=10000, interval=5)
